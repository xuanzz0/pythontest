# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cleaning = pd.read_csv('../python/assignment1_data.csv', index_col = -1)# index_col: Column to use as the row labels of the DataFrame.
df = cleaning.copy()

# %%
cleaning.head()
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         ???        2.78
# 2000/12/31 0:00   ???    ???             ???         ???         ???
# 1987/12/31 0:00   ???    ???             ???         ???         ???
# 2003/12/31 0:00   ???    ???             ???         ???         ???
# 2006/12/31 0:00   ???    ???             ???         ???         ???
#
#                 P80:P50_bhc P50:P20_bhc GINI-BHC top_10_perc_wealth_share  \
# year
# 2014/12/31 0:00        1.66         0.6     34.2                        -
# 2000/12/31 0:00         ???         ???      ???                        -
# 1987/12/31 0:00         ???         ???      ???                        -
# 2003/12/31 0:00         ???         ???      ???                        -
# 2006/12/31 0:00         ???         ???      ???                       57
#
#                 top_5_perc_wealth_share      ...       suicides_per_100000  \
# ...

# %%
cleaning['Q5:Q1'].unique()# Top-level unique method for any 1-d array-like object.
# Out:
# array(['5.8', '???', '5.61', '5.33', '5.34', '5.26', '5.31', '5.94',
#        '5.42', '4.46', '5.51', '4.13', '5.38', '5.28', '5.09', '5.88',
#        '4.04'], dtype=object)

# %%
for col in cleaning.columns:
    print(col)
    print(cleaning[col].unique())
# Out:
# Q5:Q1
# ['5.8' '???' '5.61' '5.33' '5.34' '5.26' '5.31' '5.94' '5.42' '4.46'
#  '5.51' '4.13' '5.38' '5.28' '5.09' '5.88' '4.04']
# D10:D1
# ['9.59' '???' '9.1' '8.62' '8.53' '8.66' '8.1' '9.75' '8.32' '6.35' '9.15'
#  '6.15' '8.29' '8.23' '8.03' '9.82' '6.06']
# D10:D1-4(Palma)
# ['1.36' '???' '1.25' '1.28' '1.31' '1.2' '1.44' '1.34' '1.1' '0.91' '1.3'
#  '1.23' '1.21' '1.45']
# P90:P10_bhc
# ['???' '4.14' '3.93' '3.11' '4.01' '3.68' '4.13' '4.26' '3.91' '3.79'
#  '3.43' '4.17' '3.8' '3.25' '3.31' '4.02' '3.87' '3.2' '3.98']
# P80:P20_bhc
# ['2.78' '???' '2.59' '2.56' '2.24' '2.57' '2.67' '2.68' '2.55' '2.42'
#  '2.74' '2.53' '2.32' '2.29' '2.62' '2.61' '2.52' '2.19']
# P80:P50_bhc
# ['1.66' '???' '1.62' '1.56' '1.49' '1.61' '1.65' '1.64' '1.6' '1.51'
#  '1.53' '1.48' '1.58']
# P50:P20_bhc
# ['0.6' '???' '0.63' '0.61' '0.67' '0.62' '0.64' '0.65' '0.66' '0.59'
#  '0.68']
# GINI-BHC
# ['34.2' '???' '33.8' '32.4' '27.1' '33.3' '101.5' '33' '32' '35.1' '33.1'
# ...

# %%
temp = cleaning['Q5:Q1']
temp = temp.replace('???', np.nan)
temp
# Out:
# year
# 2014/12/31 0:00     5.8
# 2000/12/31 0:00     NaN
# 1987/12/31 0:00     NaN
# 2003/12/31 0:00     NaN
# 2006/12/31 0:00     NaN
# 2016/12/31 0:00    5.61
# 1983/12/31 0:00     NaN
# 2010/12/31 0:00    5.33
# 1988/12/31 0:00     NaN
# 2002/12/31 0:00     NaN
# 1985/12/31 0:00     NaN
# 2008/12/31 0:00    5.34
# 1991/12/31 0:00     NaN
# 1998/12/31 0:00    5.26
# 2005/12/31 0:00     NaN
# 1989/12/31 0:00     NaN
# 2007/12/31 0:00    5.31
# 2011/12/31 0:00    5.94
# 2001/12/31 0:00    5.42
# 1996/12/31 0:00     NaN
# 1990/12/31 0:00    4.46
# 2004/12/31 0:00    5.51
# 1995/12/31 0:00     NaN
# 2017/12/31 0:00     NaN
# 1992/12/31 0:00     NaN
# 1982/12/31 0:00    4.13
# 1984/12/31 0:00     NaN
# 1999/12/31 0:00     NaN
# 2018/12/31 0:00     NaN
# 2013/12/31 0:00    5.38
# 2012/12/31 0:00    5.28
# 1993/12/31 0:00     NaN
# 1994/12/31 0:00    5.09
# 2015/12/31 0:00    5.88
# 1986/12/31 0:00    4.04
# 2009/12/31 0:00    5.34
# 1997/12/31 0:00     NaN
# Name: Q5:Q1, dtype: object

# %%
cleaning['Q5:Q1'] = temp 
cleaning.head()
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         ???        2.78
# 2000/12/31 0:00   NaN    ???             ???         ???         ???
# 1987/12/31 0:00   NaN    ???             ???         ???         ???
# 2003/12/31 0:00   NaN    ???             ???         ???         ???
# 2006/12/31 0:00   NaN    ???             ???         ???         ???
#
#                 P80:P50_bhc P50:P20_bhc GINI-BHC top_10_perc_wealth_share  \
# year
# 2014/12/31 0:00        1.66         0.6     34.2                        -
# 2000/12/31 0:00         ???         ???      ???                        -
# 1987/12/31 0:00         ???         ???      ???                        -
# 2003/12/31 0:00         ???         ???      ???                        -
# 2006/12/31 0:00         ???         ???      ???                       57
#
#                 top_5_perc_wealth_share      ...       suicides_per_100000  \
# ...

# %%
def clean_num(x):
    if x == '???':
        return np.nan
    return x

# %%
dirty_cols = cleaning[ ['Q5:Q1','D10:D1','D10:D1-4(Palma)','P90:P10_bhc','P80:P20_bhc','P80:P50_bhc','P50:P20_bhc','GINI-BHC']] 
dirty_cols.head()
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         ???        2.78
# 2000/12/31 0:00   NaN    ???             ???         ???         ???
# 1987/12/31 0:00   NaN    ???             ???         ???         ???
# 2003/12/31 0:00   NaN    ???             ???         ???         ???
# 2006/12/31 0:00   NaN    ???             ???         ???         ???
#
#                 P80:P50_bhc P50:P20_bhc GINI-BHC
# year
# 2014/12/31 0:00        1.66         0.6     34.2
# 2000/12/31 0:00         ???         ???      ???
# 1987/12/31 0:00         ???         ???      ???
# 2003/12/31 0:00         ???         ???      ???
# 2006/12/31 0:00         ???         ???      ???

# %%
dirty_cols.applymap(clean_num)
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         NaN        2.78
# 2000/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 1987/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2003/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2006/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2016/12/31 0:00  5.61    9.1            1.36        4.14        2.59
# 1983/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2010/12/31 0:00  5.33   8.62            1.25        3.93        2.56
# 1988/12/31 0:00   NaN    NaN             NaN        3.11        2.24
# 2002/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 1985/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2008/12/31 0:00  5.34   8.53            1.28        4.01        2.57
# ...

# %%
def clean_num(x):
    if x == '???':
        return np.nan
    if x == '-':
        return np.nan
    return x

# %%
dirty_cols = cleaning[ ['Q5:Q1','D10:D1','D10:D1-4(Palma)','P90:P10_bhc','P80:P20_bhc','P80:P50_bhc','P50:P20_bhc','GINI-BHC','top_10_perc_wealth_share']] 
dirty_cols.head()
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         ???        2.78
# 2000/12/31 0:00   NaN    ???             ???         ???         ???
# 1987/12/31 0:00   NaN    ???             ???         ???         ???
# 2003/12/31 0:00   NaN    ???             ???         ???         ???
# 2006/12/31 0:00   NaN    ???             ???         ???         ???
#
#                 P80:P50_bhc P50:P20_bhc GINI-BHC top_10_perc_wealth_share
# year
# 2014/12/31 0:00        1.66         0.6     34.2                        -
# 2000/12/31 0:00         ???         ???      ???                        -
# 1987/12/31 0:00         ???         ???      ???                        -
# 2003/12/31 0:00         ???         ???      ???                        -
# 2006/12/31 0:00         ???         ???      ???                       57

# %%
dirty_cols.applymap(clean_num)
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         NaN        2.78
# 2000/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 1987/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2003/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2006/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2016/12/31 0:00  5.61    9.1            1.36        4.14        2.59
# 1983/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2010/12/31 0:00  5.33   8.62            1.25        3.93        2.56
# 1988/12/31 0:00   NaN    NaN             NaN        3.11        2.24
# 2002/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 1985/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2008/12/31 0:00  5.34   8.53            1.28        4.01        2.57
# ...

# %%
for col in dirty_cols.columns:
    print(col)
    print(dirty_cols[col].unique())
# Out:
# Q5:Q1
# ['5.8' nan '5.61' '5.33' '5.34' '5.26' '5.31' '5.94' '5.42' '4.46' '5.51'
#  '4.13' '5.38' '5.28' '5.09' '5.88' '4.04']
# D10:D1
# ['9.59' '???' '9.1' '8.62' '8.53' '8.66' '8.1' '9.75' '8.32' '6.35' '9.15'
#  '6.15' '8.29' '8.23' '8.03' '9.82' '6.06']
# D10:D1-4(Palma)
# ['1.36' '???' '1.25' '1.28' '1.31' '1.2' '1.44' '1.34' '1.1' '0.91' '1.3'
#  '1.23' '1.21' '1.45']
# P90:P10_bhc
# ['???' '4.14' '3.93' '3.11' '4.01' '3.68' '4.13' '4.26' '3.91' '3.79'
#  '3.43' '4.17' '3.8' '3.25' '3.31' '4.02' '3.87' '3.2' '3.98']
# P80:P20_bhc
# ['2.78' '???' '2.59' '2.56' '2.24' '2.57' '2.67' '2.68' '2.55' '2.42'
#  '2.74' '2.53' '2.32' '2.29' '2.62' '2.61' '2.52' '2.19']
# P80:P50_bhc
# ['1.66' '???' '1.62' '1.56' '1.49' '1.61' '1.65' '1.64' '1.6' '1.51'
#  '1.53' '1.48' '1.58']
# P50:P20_bhc
# ['0.6' '???' '0.63' '0.61' '0.67' '0.62' '0.64' '0.65' '0.66' '0.59'
#  '0.68']
# GINI-BHC
# ['34.2' '???' '33.8' '32.4' '27.1' '33.3' '101.5' '33' '32' '35.1' '33.1'
# ...

# %%
def clean_num(x):
    if x == '???':
        return np.nan
    if x == '-':
        return np.nan
     if x == 'None':
        return np.nan
    if x == 'NAN':
        return np.nan
    return x
# Out:
#   File "<tokenize>", line 6
#     if x == 'None':
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
dirty_cols = cleaning
dirty_cols.applymap(clean_num)
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         NaN        2.78
# 2000/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 1987/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2003/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2006/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2016/12/31 0:00  5.61    9.1            1.36        4.14        2.59
# 1983/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2010/12/31 0:00  5.33   8.62            1.25        3.93        2.56
# 1988/12/31 0:00   NaN    NaN             NaN        3.11        2.24
# 2002/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 1985/12/31 0:00   NaN    NaN             NaN         NaN         NaN
# 2008/12/31 0:00  5.34   8.53            1.28        4.01        2.57
# ...

# %%
cleaning['teriary_education_participation_rate'].unique()
# Out:
# array(['10.2\\I', '10.1\\Y', nan, '12.5\\T', '13.3\\T', '9.4\\J',
#        '12.2\\N', '11.9\\U', '12.4\\O', '8.3\\U', '13.5\\B', '13.1\\V',
#        '11.0\\Q', '11.0\\X', '8.200000000000001\\U', '13.1\\T', '8.1\\O',
#        '9.4\\N', '10.6\\A', '10.8\\S', '7.3\\H', '9.8\\U', '12.4\\N',
#        '8.1\\B'], dtype=object)

# %%
temp = cleaning['teriary_education_participation_rate']
temp.iloc[0][:-2]# Purely integer-location based indexing for selection by position.
# Out:
# '10.2'

# %%
temp = cleaning['teriary_education_participation_rate']
temp = temp.str[:-2]#Vectorized string functions for Series and Index. From the beginning to the second character before the countdown
temp = temp.astype(float)
temp
# Out:
# year
# 2014/12/31 0:00    10.2
# 2000/12/31 0:00    10.1
# 1987/12/31 0:00     NaN
# 2003/12/31 0:00    12.5
# 2006/12/31 0:00    13.3
# 2016/12/31 0:00     9.4
# 1983/12/31 0:00     NaN
# 2010/12/31 0:00    12.2
# 1988/12/31 0:00     NaN
# 2002/12/31 0:00    11.9
# 1985/12/31 0:00     NaN
# 2008/12/31 0:00    12.4
# 1991/12/31 0:00     NaN
# 1998/12/31 0:00     8.3
# 2005/12/31 0:00    13.5
# 1989/12/31 0:00     NaN
# 2007/12/31 0:00    13.1
# 2011/12/31 0:00    11.0
# 2001/12/31 0:00    11.0
# 1996/12/31 0:00     8.2
# 1990/12/31 0:00     NaN
# 2004/12/31 0:00    13.1
# 1995/12/31 0:00     8.1
# 2017/12/31 0:00     NaN
# 1992/12/31 0:00     NaN
# 1982/12/31 0:00     NaN
# 1984/12/31 0:00     NaN
# 1999/12/31 0:00     9.4
# 2018/12/31 0:00     NaN
# 2013/12/31 0:00    10.6
# 2012/12/31 0:00    10.8
# 1993/12/31 0:00     NaN
# 1994/12/31 0:00     7.3
# 2015/12/31 0:00     9.8
# 1986/12/31 0:00     NaN
# 2009/12/31 0:00    12.4
# 1997/12/31 0:00     8.1
# ...

# %%
cleaning['teriary_education_participation_rate'] = temp 
cleaning.head()
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         ???        2.78
# 2000/12/31 0:00   NaN    ???             ???         ???         ???
# 1987/12/31 0:00   NaN    ???             ???         ???         ???
# 2003/12/31 0:00   NaN    ???             ???         ???         ???
# 2006/12/31 0:00   NaN    ???             ???         ???         ???
#
#                 P80:P50_bhc P50:P20_bhc GINI-BHC top_10_perc_wealth_share  \
# year
# 2014/12/31 0:00        1.66         0.6     34.2                        -
# 2000/12/31 0:00         ???         ???      ???                        -
# 1987/12/31 0:00         ???         ???      ???                        -
# 2003/12/31 0:00         ???         ???      ???                        -
# 2006/12/31 0:00         ???         ???      ???                       57
#
#                 top_5_perc_wealth_share      ...       suicides_per_100000  \
# ...

# %%
type(cleaning['education_spend_as_percent_of_GDP'])
# Out:
# pandas.core.series.Series

# %%
def clean_num(x):
        x = x[:-2]
        x = x.astype(float)
        return x

# %%
dirty_cols = cleaning[['education_spend_as_percent_of_GDP','education_spend_as_percent_of_total_gov_expenses']]
dirty_cols.head()
# Out:
#                 education_spend_as_percent_of_GDP  \
# year
# 2014/12/31 0:00                             5.2\T
# 2000/12/31 0:00                             5.0\D
# 1987/12/31 0:00                               NaN
# 2003/12/31 0:00                             5.2\K
# 2006/12/31 0:00                             6.1\Q
#
#                 education_spend_as_percent_of_total_gov_expenses
# year
# 2014/12/31 0:00                                           17.3\H
# 2000/12/31 0:00                                           16.4\E
# 1987/12/31 0:00                                              NaN
# 2003/12/31 0:00                                           17.6\F
# 2006/12/31 0:00                                           20.1\I

# %%
type(cleaning['education_spend_as_percent_of_GDP'])
# Out:
# pandas.core.series.Series

# %%
dirty_cols.applymap(clean_num)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-204-99886e17f72f> in <module>
# ----> 1 dirty_cols.applymap(clean_num)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in applymap(self, func)
#    6070             return lib.map_infer(x.astype(object).values, func)
#    6071
# -> 6072         return self.apply(infer)
#    6073
#    6074     # ----------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
# ...

# %%
temp = cleaning['education_spend_as_percent_of_GDP']
temp = temp[:-2]# From the beginning to the second character before the countdown
temp = temp.astype(float)
cleaning['education_spend_as_percent_of_GDP'] = temp 
cleaning.head(5)
# Out:
#                 Q5:Q1 D10:D1 D10:D1-4(Palma) P90:P10_bhc P80:P20_bhc  \
# year
# 2014/12/31 0:00   5.8   9.59            1.36         ???        2.78
# 2000/12/31 0:00   NaN    ???             ???         ???         ???
# 1987/12/31 0:00   NaN    ???             ???         ???         ???
# 2003/12/31 0:00   NaN    ???             ???         ???         ???
# 2006/12/31 0:00   NaN    ???             ???         ???         ???
#
#                 P80:P50_bhc P50:P20_bhc GINI-BHC top_10_perc_wealth_share  \
# year
# 2014/12/31 0:00        1.66         0.6     34.2                        -
# 2000/12/31 0:00         ???         ???      ???                        -
# 1987/12/31 0:00         ???         ???      ???                        -
# 2003/12/31 0:00         ???         ???      ???                        -
# 2006/12/31 0:00         ???         ???      ???                       57
#
#                 top_5_perc_wealth_share      ...       suicides_per_100000  \
# ...

# %%
temp = cleaning['education_spend_as_percent_of_GDP']
temp = temp[:-2]# From the beginning to the second character before the countdown
temp = temp.astype(float)
cleaning['education_spend_as_percent_of_GDP'] = temp 
cleaning.head(5)

# %%
cleaning[cleaning['depression_adult'].str.contains('.*[A-Za-z]', regex=True)]
